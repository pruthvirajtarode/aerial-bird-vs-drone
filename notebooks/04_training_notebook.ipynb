# %% [markdown]
# # Training Notebook\n\nThis notebook contains steps to train the classifier using transfer learning.\n\nRun each cell in order.

# %%
# Mount dataset (if needed)\n# Ensure `classification_dataset/` is in project root with train/valid/test subfolders
